# %%
import os
import pathlib
import pandas as pd

cwd = os.getcwd()
file_path = pathlib.Path(cwd, '..', 'data', 'AAPL.CSV')

aapl_df = pd.read_csv(file_path, index_col=0, parse_dates=True)
aapl_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-03   36.220001   36.325001   35.775002   35.875000   33.961651
# 2017-07-05   35.922501   36.197498   35.680000   36.022499   34.101276
# 2017-07-06   35.755001   35.875000   35.602501   35.682499   33.779411
# 2017-07-07   35.724998   36.187500   35.724998   36.044998   34.122581
# 2017-07-10   36.027500   36.487499   35.842499   36.264999   34.330853
# ...                ...         ...         ...         ...         ...
# 2022-06-27  142.699997  143.490005  140.970001  141.660004  141.660004
# 2022-06-28  142.130005  143.419998  137.320007  137.440002  137.440002
# 2022-06-29  137.460007  140.669998  136.669998  139.229996  139.229996
# 2022-06-30  137.250000  138.369995  133.770004  136.720001  136.720001
# 2022-07-01  136.039993  139.039993  135.660004  138.929993  138.929993
#
#               Volume
# Date
# 2017-07-03  57111200
# 2017-07-05  86278400
# 2017-07-06  96515200
# 2017-07-07  76806800
# 2017-07-10  84362400
# ...              ...
# 2022-06-27  70207900
# 2022-06-28  67083400
# 2022-06-29  66242400
# 2022-06-30  98964500
# 2022-07-01  71007500
#
# [1259 rows x 6 columns]

# %%
dt_range = pd.date_range(start="2020-03-01", end="2020-03-31")
aapl_df = aapl_df[aapl_df.index.isin(dt_range)]
aapl_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-03-02  70.570000  75.360001  69.430000  74.702499  73.581810  341397200
# 2020-03-03  75.917503  76.000000  71.449997  72.330002  71.244904  319475600
# 2020-03-04  74.110001  75.849998  73.282501  75.684998  74.549545  219178400
# 2020-03-05  73.879997  74.887497  72.852501  73.230003  72.131401  187572800
# 2020-03-06  70.500000  72.705002  70.307503  72.257500  71.173485  226176800

# %% [markdown]
# mplfinance

# %%
import mplfinance as fplt
fplt.plot(
    aapl_df,
    type='candle',
    title='Apple, March-2020',
    ylabel='Price($)'
)

# %%
fplt.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
import mplfinance as fplt

fplt.plot(
    aapl_df,
    type='candle',
    style="classic",
    title='Apple, March-2020',
    ylabel='Price($)'
)

# %%
import mplfinance as fplt
fplt.plot(
    aapl_df,
    type='candle',
    style='charles',
    title='Apple, March-2020',
    ylabel='Price($)'
)

# %%
import mplfinance as fplt
fplt.plot(
    aapl_df,
    type='candle',
    style='mike',
    title='Apple, March-2020',
    ylabel='Price($)'
)

# %% [markdown]
# Candlestick with volume

# %%
import mplfinance as fplt
fplt.plot(
    aapl_df,
    type='candle',
    style='charles',
    title='Apple, March-2020',
    ylabel='Price($)',
    volume = True,
    ylabel_lower = 'Shares\nTraded'
)

# %% [markdown]
# SHow non-trading days

# %%
import mplfinance as fplt
fplt.plot(
    aapl_df,
    type='candle',
    style='charles',
    title='Apple, March-2020',
    ylabel='Price($)',
    volume = True,
    ylabel_lower = 'Shares\nTraded',
    show_nontrading = True
)

# %% [markdown]
# Cufflinks

# %%
import cufflinks as cf
import os
import pathlib
import pandas as pd

cwd = os.getcwd()
file_path = pathlib.Path(cwd, '..', 'data', 'AAPL.CSV')

aapl_df = pd.read_csv(file_path, index_col=0, parse_dates=True)
aapl_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-03   36.220001   36.325001   35.775002   35.875000   33.961651
# 2017-07-05   35.922501   36.197498   35.680000   36.022499   34.101276
# 2017-07-06   35.755001   35.875000   35.602501   35.682499   33.779411
# 2017-07-07   35.724998   36.187500   35.724998   36.044998   34.122581
# 2017-07-10   36.027500   36.487499   35.842499   36.264999   34.330853
# ...                ...         ...         ...         ...         ...
# 2022-06-27  142.699997  143.490005  140.970001  141.660004  141.660004
# 2022-06-28  142.130005  143.419998  137.320007  137.440002  137.440002
# 2022-06-29  137.460007  140.669998  136.669998  139.229996  139.229996
# 2022-06-30  137.250000  138.369995  133.770004  136.720001  136.720001
# 2022-07-01  136.039993  139.039993  135.660004  138.929993  138.929993
#
#               Volume
# Date
# 2017-07-03  57111200
# 2017-07-05  86278400
# 2017-07-06  96515200
# 2017-07-07  76806800
# 2017-07-10  84362400
# ...              ...
# 2022-06-27  70207900
# 2022-06-28  67083400
# 2022-06-29  66242400
# 2022-06-30  98964500
# 2022-07-01  71007500
#
# [1259 rows x 6 columns]

# %%
qf = cf.QuantFig(aapl_df, title="Apple Quant Figure", legend='top', name='GS')
qf.add_bollinger_bands()
qf.add_volume()
qf.iplot()
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       2 qf.add_bollinger_bands()
#       3 qf.add_volume()
# ----> 4 qf.iplot()
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\cufflinks\quant_figure.py:1270, in QuantFig.iplot(self, **kwargs)
#    1268 	return go.Figure(fig)
#    1269 else:
# -> 1270 	return pt_iplot(fig, **export_kwargs)
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\cufflinks\plotlytools.py:1470, in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1468 	return offline.py_offline.iplot(figure, validate=validate, filename=filename, show_link=show_link, link_text=link_text, config=config)
#    1469 else:
# -> 1470 	return py.iplot(figure,validate=validate,sharing=sharing,
#    1471 					filename=filename)
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\plotly\plotly.py:135, in iplot(figure_or_data, **plot_options)
#     133 if "auto_open" not in plot_options:
#     134     plot_options["auto_open"] = False
# --> 135 url = plot(figure_or_data, **plot_options)
#     137 if isinstance(figure_or_data, dict):
#     138     layout = figure_or_data.get("layout", {})
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\plotly\plotly.py:276, in plot(figure_or_data, validate, **plot_options)
#     273 else:
#     274     grid_filename = filename + "_grid"
# --> 276 grid_ops.upload(
#     277     grid=grid,
#     278     filename=grid_filename,
#     279     world_readable=payload["world_readable"],
#     280     auto_open=False,
#     281 )
#     283 _set_grid_column_references(figure, grid)
#     284 payload["figure"] = figure
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\plotly\plotly.py:1087, in grid_ops.upload(cls, grid, filename, world_readable, auto_open, meta)
#    1084     if parent_path:
#    1085         payload["parent_path"] = parent_path
# -> 1087 file_info = _create_or_overwrite_grid(payload)
#    1089 cols = file_info["cols"]
#    1090 fid = file_info["fid"]
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\plotly\plotly.py:1550, in _create_or_overwrite_grid(data, max_retries)
#    1548 # Create file
#    1549 try:
# -> 1550     res = api_module.create(data)
#    1551 except exceptions.PlotlyRequestError as e:
#    1552     if max_retries > 0 and "already exists" in e.message:
#    1553         # Retry _create_or_overwrite
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\api\v2\grids.py:18, in create(body)
#      10 """
#      11 Create a new grid.
#      12
#    (...)
#      15
#      16 """
#      17 url = build_url(RESOURCE)
# ---> 18 return request("post", url, json=body)
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\retrying.py:49, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      47 @six.wraps(f)
#      48 def wrapped_f(*args, **kw):
# ---> 49     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\retrying.py:206, in Retrying.call(self, fn, *args, **kwargs)
#     203     attempt = Attempt(tb, attempt_number, True)
#     205 if not self.should_reject(attempt):
# --> 206     return attempt.get(self._wrap_exception)
#     208 delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#     209 if self.stop(attempt_number, delay_since_first_attempt_ms):
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\retrying.py:247, in Attempt.get(self, wrap_exception)
#     245         raise RetryError(self)
#     246     else:
# --> 247         six.reraise(self.value[0], self.value[1], self.value[2])
#     248 else:
#     249     return self.value
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\retrying.py:200, in Retrying.call(self, fn, *args, **kwargs)
#     198 while True:
#     199     try:
# --> 200         attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201     except:
#     202         tb = sys.exc_info()
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\api\v2\utils.py:180, in request(method, url, **kwargs)
#     178     content = response.content if response else "No content"
#     179     raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180 validate_response(response)
#     181 return response
#
# File D:\PSN OneDrive\OneDrive\Private\Private_Projects\Python_Projects\Data_Science_Private_Learning\venv\lib\site-packages\chart_studio\api\v2\utils.py:82, in validate_response(response)
#      79 if not message:
#      80     message = content if content else "No Content"
# ---> 82 raise exceptions.PlotlyRequestError(message, status_code, content)
#
# PlotlyRequestError: Authentication credentials were not provided.
